# %%
import pandas as pd
import pandera as pa # Utilizado para validar data

# %%
## Converter os dodos data para data
## ajustar a ordem da data: dayfirst=True
df = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
#df # imprime todas as linhas
df.head() # imprime as primerias 10 linhas

## Codigo Nat - Sem informacao de data campo data
## Codigo NaN - Campo vazio campo texto
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0            52242.0             52242.0                INCIDENTE
# 1            45331.0             45331.0                 ACIDENTE
# 2            45333.0             45333.0                 ACIDENTE
# 3            45401.0             45401.0                 ACIDENTE
# 4            45407.0             45407.0                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4          SÃO SEPÉ            RS                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0
# 4        16:30:00                    0

# %%
df.loc[1, 'ocorrencia_cidade'] # linha um coluna ocorrencia_cidade
# Out:
# 'GUARULHOS'

# %%
df.loc[3] # Dados de toda a linha 3
# Out:
# codigo_ocorrencia                         45401
# codigo_ocorrencia2                        45401
# ocorrencia_classificacao               ACIDENTE
# ocorrencia_cidade                 SÃO SEBASTIÃO
# ocorrencia_uf                                SP
# ocorrencia_aerodromo                       ****
# ocorrencia_dia              2012-01-06 00:00:00
# ocorrencia_hora                        17:00:00
# total_recomendacoes                           0
# Name: 3, dtype: object

# %%
df.loc[1:3] # dados da linha 1 ate a 3 # label
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0

# %%
df.loc[[10,40]] # informa a linha 10 e 40
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              45332               45332                 ACIDENTE
# 40              45415               45415                 ACIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10            VIAMÃO            RS                 ****     2012-01-09
# 40    RIO DE JANEIRO            RJ                 ****     2012-01-30
#
#    ocorrencia_hora  total_recomendacoes
# 10        13:30:00                    0
# 40        13:55:00                    0

# %%
df.loc[:, 'ocorrencia_cidade'] # informa todas as cidades da coluna "ocorrencia_cidade"
# Out:
# 0        PORTO ALEGRE
# 1           GUARULHOS
# 2              VIAMÃO
# 3       SÃO SEBASTIÃO
# 4            SÃO SEPÉ
#             ...
# 5162            JATAÍ
# 5163          MARACAÍ
# 5164    NOVO HAMBURGO
# 5165         CURITIBA
# 5166        PETROLINA
# Name: ocorrencia_cidade, Length: 5167, dtype: object

# %%
df.codigo_ocorrencia.is_unique # validando se o coluna "Codigo ocorrencia"tem valores unicos Pode ser utilizado para indice
# Out:
# True

# %%
df.set_index('codigo_ocorrencia', inplace=True) #Indentificando coluna com valores unicos para utilizacao como indice

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
#
#                   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 52242                  PORTO ALEGRE            RS                 SBPA
# 45331                     GUARULHOS            SP                 SBGR
# 45333                        VIAMÃO            RS                 ****
# 45401                 SÃO SEBASTIÃO            SP                 ****
# 45407                      SÃO SEPÉ            RS                 ****
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# 52242                 2012-01-05        20:27:00                    0
# 45331                 2012-01-06        13:44:00                    3
# 45333                 2012-01-06        13:00:00                    0
# 45401                 2012-01-06        17:00:00                    0
# 45407                 2012-01-06        16:30:00                    0

# %%
df.loc[45401]
# Out:
# codigo_ocorrencia2                        45401
# ocorrencia_classificacao               ACIDENTE
# ocorrencia_cidade                 SÃO SEBASTIÃO
# ocorrencia_uf                                SP
# ocorrencia_aerodromo                       ****
# ocorrencia_dia              2012-01-06 00:00:00
# ocorrencia_hora                        17:00:00
# total_recomendacoes                           0
# Name: 45401, dtype: object

# %%
df.reset_index(drop=True, inplace=True) # como remover o indice e retorar para o original

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1               45331                 ACIDENTE         GUARULHOS
# 2               45333                 ACIDENTE            VIAMÃO
# 3               45401                 ACIDENTE     SÃO SEBASTIÃO
# 4               45407                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA     2012-01-05        20:27:00
# 1            SP                 SBGR     2012-01-06        13:44:00
# 2            RS                 ****     2012-01-06        13:00:00
# 3            SP                 ****     2012-01-06        17:00:00
# 4            RS                 ****     2012-01-06        16:30:00
#
#    total_recomendacoes
# 0                    0
# 1                    3
# 2                    0
# 3                    0
# 4                    0

# %%
df.loc[2, 'ocorrencia_aerodromo'] = '' # atribui o valor "em branco" na posicao linha 2 coluna "ocorrencia_aerodromo"

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1               45331                 ACIDENTE         GUARULHOS
# 2               45333                 ACIDENTE            VIAMÃO
# 3               45401                 ACIDENTE     SÃO SEBASTIÃO
# 4               45407                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA     2012-01-05        20:27:00
# 1            SP                 SBGR     2012-01-06        13:44:00
# 2            RS                          2012-01-06        13:00:00
# 3            SP                 ****     2012-01-06        17:00:00
# 4            RS                 ****     2012-01-06        16:30:00
#
#    total_recomendacoes
# 0                    0
# 1                    3
# 2                    0
# 3                    0
# 4                    0

# %%
df.loc[2] ## Mostra a coluna ocorrencia_aerodromo e linha 2 com valor zerado devido ao comando "df.loc[2, 'ocorrencia_aerodromo'] = ''"
# Out:
# codigo_ocorrencia2                        45333
# ocorrencia_classificacao               ACIDENTE
# ocorrencia_cidade                        VIAMÃO
# ocorrencia_uf                                RS
# ocorrencia_aerodromo
# ocorrencia_dia              2012-01-06 00:00:00
# ocorrencia_hora                        13:00:00
# total_recomendacoes                           0
# Name: 2, dtype: object

# %%
df.loc[1] = 20 # Alterra todo o conteudo da linha 1 para o valor 20

# %%
df.head(2)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1                  20                       20                20
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA  2012-01-05 00:00:00        20:27:00
# 1            20                   20                   20              20
#
#    total_recomendacoes
# 0                    0
# 1                   20

# %%
df.loc[:,'total_recomendacoes'] = 10 ## Muda todos os valores da coluna: 'total_recomendacoes' para o valor 10

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                     20                       20                20
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                 ACIDENTE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                 ACIDENTE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA  2012-01-05 00:00:00        20:27:00
# 1               20                   20                   20              20
# 2               RS                       2012-01-06 00:00:00        13:00:00
# 3               SP                 ****  2012-01-06 00:00:00        17:00:00
# 4               RS                 ****  2012-01-06 00:00:00        16:30:00
# ...            ...                  ...                  ...             ...
# 5162            GO                 ####  2021-12-30 00:00:00        20:30:00
# 5163            SP                *****  2021-12-31 00:00:00        09:30:00
# 5164            RS                 SSNH  2021-12-31 00:00:00        11:59:00
# 5165            PR                 SBBI  2021-12-31 00:00:00        15:12:00
# 5166            PE                 SBPL  2021-12-31 00:00:00        20:30:00
#
#       total_recomendacoes
# 0                      10
# 1                      10
# 2                      10
# 3                      10
# 4                      10
# ...                   ...
# 5162                   10
# 5163                   10
# 5164                   10
# 5165                   10
# 5166                   10
#
# [5167 rows x 8 columns]

# %%
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf ## fazendo backup de coluna

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                     20                       20                20
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                 ACIDENTE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                 ACIDENTE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA  2012-01-05 00:00:00        20:27:00
# 1               20                   20                   20              20
# 2               RS                       2012-01-06 00:00:00        13:00:00
# 3               SP                 ****  2012-01-06 00:00:00        17:00:00
# 4               RS                 ****  2012-01-06 00:00:00        16:30:00
# ...            ...                  ...                  ...             ...
# 5162            GO                 ####  2021-12-30 00:00:00        20:30:00
# 5163            SP                *****  2021-12-31 00:00:00        09:30:00
# 5164            RS                 SSNH  2021-12-31 00:00:00        11:59:00
# 5165            PR                 SBBI  2021-12-31 00:00:00        15:12:00
# 5166            PE                 SBPL  2021-12-31 00:00:00        20:30:00
#
#       total_recomendacoes ocorrencia_uf_bkp
# 0                      10                RS
# 1                      10                20
# 2                      10                RS
# 3                      10                SP
# 4                      10                RS
# ...                   ...               ...
# 5162                   10                GO
# 5163                   10                SP
# 5164                   10                RS
# 5165                   10                PR
# 5166                   10                PE
#
# [5167 rows x 9 columns]

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE' ## Muda a classificacao de SP para grave

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                     20                       20                20
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                    GRAVE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                    GRAVE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA  2012-01-05 00:00:00        20:27:00
# 1               20                   20                   20              20
# 2               RS                       2012-01-06 00:00:00        13:00:00
# 3               SP                 ****  2012-01-06 00:00:00        17:00:00
# 4               RS                 ****  2012-01-06 00:00:00        16:30:00
# ...            ...                  ...                  ...             ...
# 5162            GO                 ####  2021-12-30 00:00:00        20:30:00
# 5163            SP                *****  2021-12-31 00:00:00        09:30:00
# 5164            RS                 SSNH  2021-12-31 00:00:00        11:59:00
# 5165            PR                 SBBI  2021-12-31 00:00:00        15:12:00
# 5166            PE                 SBPL  2021-12-31 00:00:00        20:30:00
#
#       total_recomendacoes ocorrencia_uf_bkp
# 0                      10                RS
# 1                      10                20
# 2                      10                RS
# 3                      10                SP
# 4                      10                RS
# ...                   ...               ...
# 5162                   10                GO
# 5163                   10                SP
# 5164                   10                RS
# 5165                   10                PR
# 5166                   10                PE
#
# [5167 rows x 9 columns]

# %%
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao  ocorrencia_cidade  \
# 3                  45401                    GRAVE      SÃO SEBASTIÃO
# 5                  52243                    GRAVE            UBATUBA
# 6                  50713                    GRAVE           CAMPINAS
# 13                 45408                    GRAVE           ELDORADO
# 26                 45410                    GRAVE  BRAGANÇA PAULISTA
# ...                  ...                      ...                ...
# 5148               80441                    GRAVE  BRAGANÇA PAULISTA
# 5157               80453                    GRAVE           CAMPINAS
# 5158               80454                    GRAVE          ARAÇATUBA
# 5161               80456                    GRAVE          SÃO PAULO
# 5163               80452                    GRAVE            MARACAÍ
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 3               SP                 ****  2012-01-06 00:00:00        17:00:00
# 5               SP                 ****  2012-01-06 00:00:00        14:30:00
# 6               SP                 SDAI  2012-01-07 00:00:00        18:15:00
# 13              SP                 ****  2012-01-11 00:00:00        13:45:00
# 26              SP                 SDVH  2012-01-21 00:00:00        23:30:00
# ...            ...                  ...                  ...             ...
# 5148            SP                 SDVH  2021-12-20 00:00:00        18:15:00
# 5157            SP                 SBKP  2021-12-29 00:00:00        09:00:00
# 5158            SP                 SBAU  2021-12-29 00:00:00        21:35:00
# 5161            SP                 SBSP  2021-12-30 00:00:00        13:15:00
# 5163            SP                *****  2021-12-31 00:00:00        09:30:00
#
#       total_recomendacoes ocorrencia_uf_bkp
# 3                      10                SP
# 5                      10                SP
# 6                      10                SP
# 13                     10                SP
# 26                     10                SP
# ...                   ...               ...
# 5148                   10                SP
# 5157                   10                SP
# 5158                   10                SP
# 5161                   10                SP
# 5163                   10                SP
#
# [1260 rows x 9 columns]
